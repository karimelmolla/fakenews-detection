# %%
import numpy as np
import pandas as pd
import re  # used to search words in text or paragraphs
from nltk.corpus import stopwords # to remove meaningless words such as a, the ,are.....
from nltk.stem.porter import PorterStemmer # filters the root word
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
from PIL import Image
import nltk
import string
from bs4 import BeautifulSoup
from nltk.corpus import stopwords

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
Dataset2_one = pd.read_csv("/content/Sentiment_DATA.csv")
Dataset2_two = pd.read_csv("/content/fake_news_merged_final.csv")
Dataset2_three = pd.read_csv("/content/Afinn Sentiment.csv")

# %%
Dataset2_one.nunique()
# Out:
# textID              27480
# text                27480
# sentiment               3
# Time of Tweet           3
# Age of User             6
# Country               195
# Population -2020      195
# Land Area (Km²)       193
# Density (P/Km²)       136
# selected_text       22430
# dtype: int64

# %%
Dataset2_two.nunique()
# Out:
# ID                      12786
# label                       2
# statement               12760
# subject                  4534
# speaker                  3308
# speaker_job              1354
# state_info                 84
# party_affiliation          24
# barely_true_counts         30
# false_counts               30
# half_true_counts           29
# mostly_true_counts         27
# pants_on_fire_counts       20
# context                  5140
# sentiment                   2
# sentiment_score            19
# sentiment_magnitude        36
# anger                   12474
# fear                    12410
# joy                     12522
# disgust                 12530
# sad                     12574
# speaker_id               2909
# list                        2
# sentiment_code              2
# full_text                9219
# emotion                 12778
# digit                       2
# dtype: int64

# %%
Dataset2_three.nunique()
# Out:
# Unnamed: 0            10700
# text                  10383
# sentiment_score          37
# sentiment_category        3
# dtype: int64

# %%
Dataset2_three.tail()
# Out:
#        Unnamed: 0                                               text  \
# 10695       10695  coronavirusupdates state wise detail total con...
# 10696       10696  tonight midnight onwards disaster management a...
# 10697       10697  new case covid nigeria plateau enugu oyo lagos...
# 10698       10698  rt cdcemergency dyk cdcgov one stop shop covid...
# 10699       10699  half pregnant woman recently admitted uk hospi...
#
#        sentiment_score sentiment_category
# 10695              0.0            neutral
# 10696             -3.0           negative
# 10697             -2.0           negative
# 10698             -1.0           negative
# 10699             -3.0           negative

# %%
Dataset2_one.head()
# Out:
#        textID                                               text sentiment  \
# 0  cb774db0d1                I`d have responded, if I were going   neutral
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!  negative
# 2  088c60f138                          my boss is bullying me...  negative
# 3  9642c003ef                     what interview! leave me alone  negative
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...  negative
#
#   Time of Tweet Age of User      Country  Population -2020  Land Area (Km²)  \
# 0       morning        0-20  Afghanistan        38928346.0         652860.0
# 1          noon       21-30      Albania         2877797.0          27400.0
# 2         night       31-45      Algeria        43851044.0        2381740.0
# 3       morning       46-60      Andorra           77265.0            470.0
# 4          noon       60-70       Angola        32866272.0        1246700.0
#
#    Density (P/Km²)                        selected_text
# ...

# %%
Dataset2_two.head()
# Out:
#            ID  label                                          statement  \
# 0   2635.json  False  Says the Annies List political group supports ...
# 1  10540.json   True  When did the decline of coal start? It started...
# 2    324.json   True  Hillary Clinton agrees with John McCain "by vo...
# 3   1123.json  False  Health care reform legislation is likely to ma...
# 4   9028.json   True  The economic turnaround started at the end of ...
#
#                               subject         speaker           speaker_job  \
# 0                            abortion    dwayne-bohac  State representative
# 1  energy,history,job-accomplishments  scott-surovell        State delegate
# 2                      foreign-policy    barack-obama             President
# 3                         health-care    blog-posting                   NaN
# 4                        economy,jobs   charlie-crist                   NaN
#
#   state_info party_affiliation  barely_true_counts  false_counts  ...  \
# ...

# %%
Dataset2_two["text"] = Dataset2_two["statement"] + Dataset2_two["full_text"]
Dataset2_two.sample(frac = 1) #Shuffle 100%
# Out:
#                ID  label                                          statement  \
# 6511    7861.json  False  Says first eight chosen to draw Austin City Co...
# 12265   4371.json   True  Says that in 2009 ExxonMobil paid no federal i...
# 10783  12929.json   True  Today California is kicking our butt, creating...
# 309     2076.json   True  Have the suburbs been inundated with former re...
# 1618   12920.json  False  Because theres no local option to allow commun...
# ...           ...    ...                                                ...
# 9856    3658.json  False                 President Obama was raised Muslim.
# 6606   13146.json  False  Says Tom Nelson backed higher taxes on Social ...
# 10207   1550.json   True  Debt has almost doubled in Austin under Gov. P...
# 5682   11164.json  False  The Mexican government ... they send the bad o...
# 3296    4821.json   True  Community banks are being destroyed by Dodd-Fr...
#
# ...

# %%
Dataset2_one.sample(frac = 1) #Shuffle 100%
# Out:
#            textID                                               text  \
# 3076   a0e9f216f2                  This is truly enlightening for me
# 4830   64e197bc57                            may the 4th be with you
# 13301  add3a63b8a       Is in bed not able to sleep  bloody bipolar!
# 15497  81876c9769   Hey chick!  When are we going to JA to pick u...
# 7771   f4fef232da  Is looking forward to a yummy dinner with mizz...
# ...           ...                                                ...
# 2495   8f1d4e2353           http://bit.ly/UnRyF  I want this, but...
# 7696   f173c68653  is wishing everyone a blessed & beautiful Moth...
# 306    b7a9ba95d0          Dinner with the fam... I have missed them
# 20223  35ed8c91a8    Yes thanks, its been great. Soooooo not look...
# 27065  5aa5e13395  long, fun day  now for some relaxation. some T...
#
#       sentiment Time of Tweet Age of User                           Country  \
# ...

# %%
Dataset2_three["sentiment"] = Dataset2_three["sentiment_category"]
Dataset2_three.sample(frac = 1) #Shuffle 100%
# Out:
#        Unnamed: 0                                               text  \
# 10662       10662  return higher testing number driven south west...
# 2400         2400  estimate suggest effective covid vaccine distr...
# 4355         4355             pcr test also detect common cold virus
# 916           916  new case remained yesterday day average pretty...
# 8723         8723  bechara covid se hai else would give nice acce...
# ...           ...                                                ...
# 3528         3528  whatsapp message allegedly chinese doctor cnn ...
# 3355         3355  yorkshirebri latimeralder expert big pharma re...
# 8562         8562  president trump asked would catch coronavirus ...
# 8434         8434  three story evening covid alert level upgraded...
# 156           156  today total active covid case india sample tes...
#
#        sentiment_score sentiment_category sentiment
# 10662              0.0            neutral   neutral
# ...

# %%
Dataset2_three = Dataset2_three.loc[:,['text','sentiment']]
Dataset2_three = Dataset2_three.dropna()

# %%
Dataset2_three
# Out:
#                                                     text sentiment
# 0      cdc currently report death general discrepancy...  negative
# 1      state reported death small rise last tuesday s...  negative
# 2      politically correct woman almost us pandemic e...  negative
# 3      indiafightscorona covid testing laboratory ind...   neutral
# 4      populous state generate large case count look ...   neutral
# ...                                                  ...       ...
# 10695  coronavirusupdates state wise detail total con...   neutral
# 10696  tonight midnight onwards disaster management a...  negative
# 10697  new case covid nigeria plateau enugu oyo lagos...  negative
# 10698  rt cdcemergency dyk cdcgov one stop shop covid...  negative
# 10699  half pregnant woman recently admitted uk hospi...  negative
#
# [10700 rows x 2 columns]

# %%
Dataset2_one = Dataset2_one.loc[:,['text','sentiment']]
Dataset2_one = Dataset2_one.dropna()

# %%
Dataset2_one
# Out:
#                                                     text sentiment
# 0                    I`d have responded, if I were going   neutral
# 1          Sooo SAD I will miss you here in San Diego!!!  negative
# 2                              my boss is bullying me...  negative
# 3                         what interview! leave me alone  negative
# 4       Sons of ****, why couldn`t they put them on t...  negative
# ...                                                  ...       ...
# 27475   wish we could come see u on Denver  husband l...  negative
# 27476   I`ve wondered about rake to.  The client has ...  negative
# 27477   Yay good for both of you. Enjoy the break - y...  positive
# 27478                         But it was worth it  ****.  positive
# 27479     All this flirting going on - The ATG smiles...   neutral
#
# [27480 rows x 2 columns]

# %%
Dataset2_two = Dataset2_two.loc[:,['text','sentiment']]
Dataset2_two = Dataset2_two.dropna()

# %%
Dataset2_two.head()
# Out:
#                                                 text sentiment
# 0  Says the Annies List political group supports ...  NEGATIVE
# 1  When did the decline of coal start? It started...  NEGATIVE
# 2  Hillary Clinton agrees with John McCain "by vo...  NEGATIVE
# 5  The Chicago Bears have had more starting quart...  NEGATIVE
# 7  I'm the only person on this stage who has work...  NEGATIVE

# %%
Dataset2_two.text[1]
# Out:
# 'When did the decline of coal start? It started when natural gas took off that started to begin in (President George W.) Bushs administration.energy history job accomplishments when did the decline of coal start it started when natural gas took off that started to begin in president george w bushs administration 1 state delegate democrat '

# %%
Dataset2_two.sentiment[Dataset2_two.sentiment == 'NEGATIVE'] = "negative"
Dataset2_two.sentiment[Dataset2_two.sentiment == 'POSITIVE'] = "positive"

# %%
Dataset2_two
# Out:
#                                                     text sentiment
# 0      Says the Annies List political group supports ...  negative
# 1      When did the decline of coal start? It started...  negative
# 2      Hillary Clinton agrees with John McCain "by vo...  negative
# 5      The Chicago Bears have had more starting quart...  negative
# 7      I'm the only person on this stage who has work...  negative
# ...                                                  ...       ...
# 12778  Says U.S. Rep. Charles Bass wants to privatize...  negative
# 12780  In the past two years, Democrats have spent mo...  negative
# 12781  For the first time in more than a decade, impo...  negative
# 12782  Says Donald Trump has bankrupted his companies...  negative
# 12785  No one claims the report vindicating New Jerse...  negative
#
# [7974 rows x 2 columns]

# %%
Dataset2_one
# Out:
#                                                     text sentiment
# 0                    I`d have responded, if I were going   neutral
# 1          Sooo SAD I will miss you here in San Diego!!!  negative
# 2                              my boss is bullying me...  negative
# 3                         what interview! leave me alone  negative
# 4       Sons of ****, why couldn`t they put them on t...  negative
# ...                                                  ...       ...
# 27475   wish we could come see u on Denver  husband l...  negative
# 27476   I`ve wondered about rake to.  The client has ...  negative
# 27477   Yay good for both of you. Enjoy the break - y...  positive
# 27478                         But it was worth it  ****.  positive
# 27479     All this flirting going on - The ATG smiles...   neutral
#
# [27480 rows x 2 columns]

# %%
# Combine all datasets into one
frames = [Dataset2_one, Dataset2_two,Dataset2_three]
Dataset = pd.concat(frames, ignore_index=True)

# %%
Dataset
# Out:
#                                                     text sentiment
# 0                    I`d have responded, if I were going   neutral
# 1          Sooo SAD I will miss you here in San Diego!!!  negative
# 2                              my boss is bullying me...  negative
# 3                         what interview! leave me alone  negative
# 4       Sons of ****, why couldn`t they put them on t...  negative
# ...                                                  ...       ...
# 46149  coronavirusupdates state wise detail total con...   neutral
# 46150  tonight midnight onwards disaster management a...  negative
# 46151  new case covid nigeria plateau enugu oyo lagos...  negative
# 46152  rt cdcemergency dyk cdcgov one stop shop covid...  negative
# 46153  half pregnant woman recently admitted uk hospi...  negative
#
# [46154 rows x 2 columns]

# %%
Dataset.nunique()
# Out:
# text         45834
# sentiment        3
# dtype: int64

# %%
# Check for null values
null_values = Dataset.isnull().sum()

print("Null values in each column:")
print(null_values)
# Out:
# Null values in each column:
# text         0
# sentiment    0
# dtype: int64

# %%
Dataset.to_csv(r"Sentiment Dataset Preprocessing.csv",index=False)
